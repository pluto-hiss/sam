# %% [markdown]
# # 🎨 Meta SAM 3 to 3D Model Generator
#
# This notebook runs the **SAM to 3D** pipeline, using **SAM 3** to isolate the object of interest and **TripoSR** to generate a 3D model (.obj) from it in under a second.

# %% [markdown]
# ### 🚀 Step 1: Set Up Directory & Pull Latest Code

# %%
import os
# Ensure we are in /content/sam
if not os.path.exists('/content/sam'):
  # !git clone https://github.com/pluto-hiss/sam /content/sam
# %cd /content/sam
# !git pull

# %% [markdown]
# ### 📦 Step 2: Install Dependencies
# We pin `setuptools<81` for compatibility, install requirements, and build `torchmcubes` from source (not on PyPI).

# %%
# !pip install "setuptools<81"
# !pip install -r requirements.txt
# !pip install git+https://github.com/tatsy/torchmcubes.git

# %% [markdown]
# ### 🦖 Step 3: Clone TripoSR Repository
# We clone TripoSR locally so we can import its reconstruction modules in our python application.

# %%
import os
if not os.path.exists('TripoSR'):
  # !git clone https://github.com/VAST-AI-Research/TripoSR.git
else:
  print('TripoSR repository already cloned!')

# %% [markdown]
# ### ⚡ Step 4: Run Verification Test
# Let's run a quick verification test to ensure SAM 3 and TripoSR can load and run successfully on dummy data.

# %%
# !python test_3d_pipeline.py

# %% [markdown]
# ### 🎨 Step 5: Launch the Gradio Web App
# Run this cell to start the web app. It will output a public **Gradio Live Link** (e.g. `https://xxxx.gradio.live`) which you can click to open the app page!

# %%
# !python app.py
